# %%
import pandas as pd
import json
import time
from sqlalchemy import create_engine
from selenium import webdriver
from mysql_con import con

# creat date range
date_list = pd.date_range(end=pd.datetime.today(), periods=3650).tolist()

# required function
def fruitCrawler(date_target):
    try:
        if date_target.year > 2010:
            date_RE_target = "%s%s" % (str(date_target.year-1911), date_target.strftime("/%m/%d")) 
        else:
            date_RE_target = "0%s%s" % (str(date_target.year-1911), date_target.strftime("/%m/%d"))
        # date select
        driver.find_element_by_name("ctl00$contentPlaceHolder$txtSTransDate").click()
        driver.execute_script("setValue('%s');" % date_RE_target)
        # submit
        driver.find_element_by_name("ctl00$contentPlaceHolder$btnQuery").click()
        time.sleep(3)
        # find table
        res = driver.find_element_by_xpath("//div[@id='ctl00_contentPlaceHolder_panel']")
        content = res.get_attribute('innerHTML')
        print("Crawler state " + date_target.strftime("%Y/%m/%d") + " complete!")
        return content
    except Exception as e:
        driver.switch_to.alert.accept()
        print(e)

def fruitTransform(content, date_target):
    try:
        tmp = pd.read_html(content, header=0)[2]
        df = pd.DataFrame(tmp).drop(0)
        df.dropna(inplace=True)

        # clean column_1
        str1 = [i.split(" ")[0] for i in df.iloc[:,0]]
        df.iloc[:,0] = [int(i) for i in str1]
        # clean column_2
        df.iloc[:,1] = [i.split(" ")[0] for i in df.iloc[:,1]]

        df.drop(df.columns[[6,8]], axis=1, inplace=True)
        df.columns = ["market", "produce", "price_top", "price_mid", "price_low", "price_ave", "volumn"]
        df["date_"] = date_target.strftime("%Y/%m/%d")

        print("Transform state " + date_target.strftime("%Y/%m/%d") + " complete!")
        return df
    except Exception as e:
        print(e)

def fruitMySQL(df, con):
    try:
        df.to_sql('price',con=con(),if_exists='append',index=False)
        print("DB store complete!")
    except Exception as e:
        print(e)

# %%
# initialize
driver = webdriver.Chrome("/Users/timchen/Documents/chromedriver")
driver.get("http://amis.afa.gov.tw/main/Main.aspx")
driver.find_element_by_xpath("//li[2]/a[@class='menu-01']").click() # menu
driver.find_element_by_xpath("//li[1]/a[@class='map_menu_layer01_nopic']").click() # topic
driver.find_element_by_xpath("//textarea[@id='ctl00_contentPlaceHolder_txtMarket']").click() # produce
driver.switch_to.frame(driver.find_element_by_tag_name("iframe")) # switch frame
driver.find_element_by_id("radlMarketRange_0").click() # all produce
driver.find_element_by_name("ctl00$contentPlaceHolder$txtProduct").click() # market
driver.switch_to.frame(driver.find_element_by_tag_name("iframe")) # switch frame
driver.find_element_by_id("radlProductType_0").click() # all market

# %%
for i,j in enumerate(date_list[3407:]):
    tmp_content = fruitCrawler(j)
    tmp_df = fruitTransform(tmp_content, j)
    fruitMySQL(tmp_df, con=engine)
# Out:
# Crawler state 2017/12/22 complete!
# Transform state 2017/12/22 complete!
# DB store complete!
# Crawler state 2017/12/23 complete!
# Transform state 2017/12/23 complete!
# DB store complete!
# Crawler state 2017/12/24 complete!
# Transform state 2017/12/24 complete!
# DB store complete!
# Crawler state 2017/12/25 complete!
# Transform state 2017/12/25 complete!
# DB store complete!
# Crawler state 2017/12/26 complete!
# Transform state 2017/12/26 complete!
# DB store complete!
# Crawler state 2017/12/27 complete!
# Transform state 2017/12/27 complete!
# DB store complete!
# Crawler state 2017/12/28 complete!
# Transform state 2017/12/28 complete!
# DB store complete!
# Crawler state 2017/12/29 complete!
# Transform state 2017/12/29 complete!
# DB store complete!
# Crawler state 2017/12/30 complete!
# Transform state 2017/12/30 complete!
# DB store complete!
# Crawler state 2017/12/31 complete!
# Transform state 2017/12/31 complete!
# DB store complete!
# Crawler state 2018/01/01 complete!
# Transform state 2018/01/01 complete!
# DB store complete!
# Crawler state 2018/01/02 complete!
# Transform state 2018/01/02 complete!
# DB store complete!
# Crawler state 2018/01/03 complete!
# Transform state 2018/01/03 complete!
# DB store complete!
# Crawler state 2018/01/04 complete!
# Transform state 2018/01/04 complete!
# DB store complete!
# Crawler state 2018/01/05 complete!
# Transform state 2018/01/05 complete!
# DB store complete!
# Crawler state 2018/01/06 complete!
# Transform state 2018/01/06 complete!
# DB store complete!
# Crawler state 2018/01/07 complete!
# Transform state 2018/01/07 complete!
# DB store complete!
# Crawler state 2018/01/08 complete!
# Transform state 2018/01/08 complete!
# DB store complete!
# Crawler state 2018/01/09 complete!
# Transform state 2018/01/09 complete!
# DB store complete!
# Crawler state 2018/01/10 complete!
# Transform state 2018/01/10 complete!
# DB store complete!
# Crawler state 2018/01/11 complete!
# Transform state 2018/01/11 complete!
# DB store complete!
# Crawler state 2018/01/12 complete!
# Transform state 2018/01/12 complete!
# DB store complete!
# Crawler state 2018/01/13 complete!
# Transform state 2018/01/13 complete!
# DB store complete!
# Crawler state 2018/01/14 complete!
# Transform state 2018/01/14 complete!
# DB store complete!
# Crawler state 2018/01/15 complete!
# Transform state 2018/01/15 complete!
# DB store complete!
# Crawler state 2018/01/16 complete!
# Transform state 2018/01/16 complete!
# DB store complete!
# Crawler state 2018/01/17 complete!
# Transform state 2018/01/17 complete!
# DB store complete!
# Crawler state 2018/01/18 complete!
# Transform state 2018/01/18 complete!
# DB store complete!
# Crawler state 2018/01/19 complete!
# Transform state 2018/01/19 complete!
# DB store complete!
# Crawler state 2018/01/20 complete!
# Transform state 2018/01/20 complete!
# DB store complete!
# Crawler state 2018/01/21 complete!
# Transform state 2018/01/21 complete!
# DB store complete!
# Crawler state 2018/01/22 complete!
# Transform state 2018/01/22 complete!
# DB store complete!
# Crawler state 2018/01/23 complete!
# Transform state 2018/01/23 complete!
# DB store complete!
# Crawler state 2018/01/24 complete!
# Transform state 2018/01/24 complete!
# DB store complete!
# Crawler state 2018/01/25 complete!
# Transform state 2018/01/25 complete!
# DB store complete!
# Crawler state 2018/01/26 complete!
# Transform state 2018/01/26 complete!
# DB store complete!
# Crawler state 2018/01/27 complete!
# Transform state 2018/01/27 complete!
# DB store complete!
# Crawler state 2018/01/28 complete!
# Transform state 2018/01/28 complete!
# DB store complete!
# Crawler state 2018/01/29 complete!
# Transform state 2018/01/29 complete!
# DB store complete!
# Crawler state 2018/01/30 complete!
# Transform state 2018/01/30 complete!
# DB store complete!
# Crawler state 2018/01/31 complete!
# Transform state 2018/01/31 complete!
# DB store complete!
# Crawler state 2018/02/01 complete!
# Transform state 2018/02/01 complete!
# DB store complete!
# Crawler state 2018/02/02 complete!
# Transform state 2018/02/02 complete!
# DB store complete!
# Crawler state 2018/02/03 complete!
# Transform state 2018/02/03 complete!
# DB store complete!
# Crawler state 2018/02/04 complete!
# Transform state 2018/02/04 complete!
# DB store complete!
# Crawler state 2018/02/05 complete!
# Transform state 2018/02/05 complete!
# DB store complete!
# Crawler state 2018/02/06 complete!
# Transform state 2018/02/06 complete!
# DB store complete!
# Crawler state 2018/02/07 complete!
# Transform state 2018/02/07 complete!
# DB store complete!
# Crawler state 2018/02/08 complete!
# Transform state 2018/02/08 complete!
# DB store complete!
# Crawler state 2018/02/09 complete!
# Transform state 2018/02/09 complete!
# DB store complete!
# Crawler state 2018/02/10 complete!
# Transform state 2018/02/10 complete!
# DB store complete!
# Crawler state 2018/02/11 complete!
# Transform state 2018/02/11 complete!
# DB store complete!
# Crawler state 2018/02/12 complete!
# Transform state 2018/02/12 complete!
# DB store complete!
# Crawler state 2018/02/13 complete!
# Transform state 2018/02/13 complete!
# DB store complete!
# Crawler state 2018/02/14 complete!
# Transform state 2018/02/14 complete!
# DB store complete!
# Crawler state 2018/02/15 complete!
# Transform state 2018/02/15 complete!
# DB store complete!
# Alert Text: None
# Message: unexpected alert open: {Alert text : 查無符合條件資料}
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.4 x86_64)
#
# Cannot read object of type 'NoneType'
# 'NoneType' object has no attribute 'to_sql'
# Alert Text: None
# Message: unexpected alert open: {Alert text : 查無符合條件資料}
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.4 x86_64)
#
# Cannot read object of type 'NoneType'
# 'NoneType' object has no attribute 'to_sql'
# Alert Text: None
# Message: unexpected alert open: {Alert text : 查無符合條件資料}
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.4 x86_64)
#
# Cannot read object of type 'NoneType'
# 'NoneType' object has no attribute 'to_sql'
# Alert Text: None
# Message: unexpected alert open: {Alert text : 查無符合條件資料}
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.4 x86_64)
#
# Cannot read object of type 'NoneType'
# 'NoneType' object has no attribute 'to_sql'
# Alert Text: None
# Message: unexpected alert open: {Alert text : 查無符合條件資料}
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.4 x86_64)
#
# Cannot read object of type 'NoneType'
# 'NoneType' object has no attribute 'to_sql'
# Crawler state 2018/02/21 complete!
# Transform state 2018/02/21 complete!
# DB store complete!
# Crawler state 2018/02/22 complete!
# Transform state 2018/02/22 complete!
# DB store complete!
# Crawler state 2018/02/23 complete!
# Transform state 2018/02/23 complete!
# DB store complete!
# Crawler state 2018/02/24 complete!
# Transform state 2018/02/24 complete!
# DB store complete!
# Crawler state 2018/02/25 complete!
# Transform state 2018/02/25 complete!
# DB store complete!
# Crawler state 2018/02/26 complete!
# Transform state 2018/02/26 complete!
# DB store complete!
# Crawler state 2018/02/27 complete!
# Transform state 2018/02/27 complete!
# DB store complete!
# Crawler state 2018/02/28 complete!
# Transform state 2018/02/28 complete!
# DB store complete!
# Crawler state 2018/03/01 complete!
# Transform state 2018/03/01 complete!
# DB store complete!
# Crawler state 2018/03/02 complete!
# Transform state 2018/03/02 complete!
# DB store complete!
# Crawler state 2018/03/03 complete!
# Transform state 2018/03/03 complete!
# DB store complete!
# Crawler state 2018/03/04 complete!
# Transform state 2018/03/04 complete!
# DB store complete!
# Crawler state 2018/03/05 complete!
# Transform state 2018/03/05 complete!
# DB store complete!
# Crawler state 2018/03/06 complete!
# Transform state 2018/03/06 complete!
# DB store complete!
# Crawler state 2018/03/07 complete!
# Transform state 2018/03/07 complete!
# DB store complete!
# Crawler state 2018/03/08 complete!
# Transform state 2018/03/08 complete!
# DB store complete!
# Crawler state 2018/03/09 complete!
# Transform state 2018/03/09 complete!
# DB store complete!
# Crawler state 2018/03/10 complete!
# Transform state 2018/03/10 complete!
# DB store complete!
# Crawler state 2018/03/11 complete!
# Transform state 2018/03/11 complete!
# DB store complete!
# Crawler state 2018/03/12 complete!
# Transform state 2018/03/12 complete!
# DB store complete!
# Crawler state 2018/03/13 complete!
# Transform state 2018/03/13 complete!
# DB store complete!
# Crawler state 2018/03/14 complete!
# Transform state 2018/03/14 complete!
# DB store complete!
# Crawler state 2018/03/15 complete!
# Transform state 2018/03/15 complete!
# DB store complete!
# Crawler state 2018/03/16 complete!
# Transform state 2018/03/16 complete!
# DB store complete!
# Crawler state 2018/03/17 complete!
# Transform state 2018/03/17 complete!
# DB store complete!
# Crawler state 2018/03/18 complete!
# Transform state 2018/03/18 complete!
# DB store complete!
# Crawler state 2018/03/19 complete!
# Transform state 2018/03/19 complete!
# DB store complete!
# Crawler state 2018/03/20 complete!
# Transform state 2018/03/20 complete!
# DB store complete!
# Crawler state 2018/03/21 complete!
# Transform state 2018/03/21 complete!
# DB store complete!
# Crawler state 2018/03/22 complete!
# Transform state 2018/03/22 complete!
# DB store complete!
# Crawler state 2018/03/23 complete!
# Transform state 2018/03/23 complete!
# DB store complete!
# Crawler state 2018/03/24 complete!
# Transform state 2018/03/24 complete!
# DB store complete!
# Crawler state 2018/03/25 complete!
# Transform state 2018/03/25 complete!
# DB store complete!
# Crawler state 2018/03/26 complete!
# Transform state 2018/03/26 complete!
# DB store complete!
# Crawler state 2018/03/27 complete!
# Transform state 2018/03/27 complete!
# DB store complete!
# Crawler state 2018/03/28 complete!
# Transform state 2018/03/28 complete!
# DB store complete!
# Crawler state 2018/03/29 complete!
# Transform state 2018/03/29 complete!
# DB store complete!
# Crawler state 2018/03/30 complete!
# Transform state 2018/03/30 complete!
# DB store complete!
# Crawler state 2018/03/31 complete!
# Transform state 2018/03/31 complete!
# DB store complete!
# Crawler state 2018/04/01 complete!
# Transform state 2018/04/01 complete!
# DB store complete!
# Crawler state 2018/04/02 complete!
# Transform state 2018/04/02 complete!
# DB store complete!
# Crawler state 2018/04/03 complete!
# Transform state 2018/04/03 complete!
# DB store complete!
# Crawler state 2018/04/04 complete!
# Transform state 2018/04/04 complete!
# DB store complete!
# Crawler state 2018/04/05 complete!
# Transform state 2018/04/05 complete!
# DB store complete!
# Crawler state 2018/04/06 complete!
# Transform state 2018/04/06 complete!
# DB store complete!
# Crawler state 2018/04/07 complete!
# Transform state 2018/04/07 complete!
# DB store complete!
# Crawler state 2018/04/08 complete!
# Transform state 2018/04/08 complete!
# DB store complete!
# Crawler state 2018/04/09 complete!
# Transform state 2018/04/09 complete!
# DB store complete!
# Crawler state 2018/04/10 complete!
# Transform state 2018/04/10 complete!
# DB store complete!
# Crawler state 2018/04/11 complete!
# Transform state 2018/04/11 complete!
# DB store complete!
# Crawler state 2018/04/12 complete!
# Transform state 2018/04/12 complete!
# DB store complete!
# Crawler state 2018/04/13 complete!
# Transform state 2018/04/13 complete!
# DB store complete!
# Crawler state 2018/04/14 complete!
# Transform state 2018/04/14 complete!
# DB store complete!
# Crawler state 2018/04/15 complete!
# Transform state 2018/04/15 complete!
# DB store complete!
# Crawler state 2018/04/16 complete!
# Transform state 2018/04/16 complete!
# DB store complete!
# Crawler state 2018/04/17 complete!
# Transform state 2018/04/17 complete!
# DB store complete!
# Crawler state 2018/04/18 complete!
# Transform state 2018/04/18 complete!
# DB store complete!
# Crawler state 2018/04/19 complete!
# Transform state 2018/04/19 complete!
# DB store complete!
# Crawler state 2018/04/20 complete!
# Transform state 2018/04/20 complete!
# DB store complete!
# Crawler state 2018/04/21 complete!
# Transform state 2018/04/21 complete!
# DB store complete!
# Crawler state 2018/04/22 complete!
# Transform state 2018/04/22 complete!
# DB store complete!
# Crawler state 2018/04/23 complete!
# Transform state 2018/04/23 complete!
# DB store complete!
# Crawler state 2018/04/24 complete!
# Transform state 2018/04/24 complete!
# DB store complete!
# Crawler state 2018/04/25 complete!
# Transform state 2018/04/25 complete!
# DB store complete!
# Crawler state 2018/04/26 complete!
# Transform state 2018/04/26 complete!
# DB store complete!
# Crawler state 2018/04/27 complete!
# Transform state 2018/04/27 complete!
# DB store complete!
# Crawler state 2018/04/28 complete!
# Transform state 2018/04/28 complete!
# DB store complete!
# Crawler state 2018/04/29 complete!
# Transform state 2018/04/29 complete!
# DB store complete!
# Crawler state 2018/04/30 complete!
# Transform state 2018/04/30 complete!
# DB store complete!
# Crawler state 2018/05/01 complete!
# Transform state 2018/05/01 complete!
# DB store complete!
# Crawler state 2018/05/02 complete!
# Transform state 2018/05/02 complete!
# DB store complete!
# Crawler state 2018/05/03 complete!
# Transform state 2018/05/03 complete!
# DB store complete!
# Crawler state 2018/05/04 complete!
# Transform state 2018/05/04 complete!
# DB store complete!
# Crawler state 2018/05/05 complete!
# Transform state 2018/05/05 complete!
# DB store complete!
# Crawler state 2018/05/06 complete!
# Transform state 2018/05/06 complete!
# DB store complete!
# Crawler state 2018/05/07 complete!
# Transform state 2018/05/07 complete!
# DB store complete!
# Crawler state 2018/05/08 complete!
# Transform state 2018/05/08 complete!
# DB store complete!
# Crawler state 2018/05/09 complete!
# Transform state 2018/05/09 complete!
# DB store complete!
# Crawler state 2018/05/10 complete!
# Transform state 2018/05/10 complete!
# DB store complete!
# Crawler state 2018/05/11 complete!
# Transform state 2018/05/11 complete!
# DB store complete!
# Crawler state 2018/05/12 complete!
# Transform state 2018/05/12 complete!
# DB store complete!
# Crawler state 2018/05/13 complete!
# Transform state 2018/05/13 complete!
# DB store complete!
# Crawler state 2018/05/14 complete!
# Transform state 2018/05/14 complete!
# DB store complete!
# Crawler state 2018/05/15 complete!
# Transform state 2018/05/15 complete!
# DB store complete!
# Crawler state 2018/05/16 complete!
# Transform state 2018/05/16 complete!
# DB store complete!
# Crawler state 2018/05/17 complete!
# Transform state 2018/05/17 complete!
# DB store complete!
# Crawler state 2018/05/18 complete!
# Transform state 2018/05/18 complete!
# DB store complete!
# Crawler state 2018/05/19 complete!
# Transform state 2018/05/19 complete!
# DB store complete!
# Crawler state 2018/05/20 complete!
# Transform state 2018/05/20 complete!
# DB store complete!
# Crawler state 2018/05/21 complete!
# Transform state 2018/05/21 complete!
# DB store complete!
# Crawler state 2018/05/22 complete!
# Transform state 2018/05/22 complete!
# DB store complete!
# Crawler state 2018/05/23 complete!
# Transform state 2018/05/23 complete!
# DB store complete!
# Crawler state 2018/05/24 complete!
# Transform state 2018/05/24 complete!
# DB store complete!
# Crawler state 2018/05/25 complete!
# Transform state 2018/05/25 complete!
# DB store complete!
# Crawler state 2018/05/26 complete!
# Transform state 2018/05/26 complete!
# DB store complete!
# Crawler state 2018/05/27 complete!
# Transform state 2018/05/27 complete!
# DB store complete!
# Crawler state 2018/05/28 complete!
# Transform state 2018/05/28 complete!
# DB store complete!
# Crawler state 2018/05/29 complete!
# Transform state 2018/05/29 complete!
# DB store complete!
# Crawler state 2018/05/30 complete!
# Transform state 2018/05/30 complete!
# DB store complete!
# Crawler state 2018/05/31 complete!
# Transform state 2018/05/31 complete!
# DB store complete!
# Crawler state 2018/06/01 complete!
# Transform state 2018/06/01 complete!
# DB store complete!
# Crawler state 2018/06/02 complete!
# Transform state 2018/06/02 complete!
# DB store complete!
# Crawler state 2018/06/03 complete!
# Transform state 2018/06/03 complete!
# DB store complete!
# Crawler state 2018/06/04 complete!
# Transform state 2018/06/04 complete!
# DB store complete!
# Crawler state 2018/06/05 complete!
# Transform state 2018/06/05 complete!
# DB store complete!
# Crawler state 2018/06/06 complete!
# Transform state 2018/06/06 complete!
# DB store complete!
# Crawler state 2018/06/07 complete!
# Transform state 2018/06/07 complete!
# DB store complete!
# Crawler state 2018/06/08 complete!
# Transform state 2018/06/08 complete!
# DB store complete!
# Crawler state 2018/06/09 complete!
# Transform state 2018/06/09 complete!
# DB store complete!
# Crawler state 2018/06/10 complete!
# Transform state 2018/06/10 complete!
# DB store complete!
# Crawler state 2018/06/11 complete!
# Transform state 2018/06/11 complete!
# DB store complete!
# Crawler state 2018/06/12 complete!
# Transform state 2018/06/12 complete!
# DB store complete!
# Crawler state 2018/06/13 complete!
# Transform state 2018/06/13 complete!
# DB store complete!
# Crawler state 2018/06/14 complete!
# Transform state 2018/06/14 complete!
# DB store complete!
# Crawler state 2018/06/15 complete!
# Transform state 2018/06/15 complete!
# DB store complete!
# Crawler state 2018/06/16 complete!
# Transform state 2018/06/16 complete!
# DB store complete!
# Crawler state 2018/06/17 complete!
# Transform state 2018/06/17 complete!
# DB store complete!
# Crawler state 2018/06/18 complete!
# Transform state 2018/06/18 complete!
# DB store complete!
# Alert Text: None
# Message: unexpected alert open: {Alert text : 查無符合條件資料}
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.4 x86_64)
#
# Cannot read object of type 'NoneType'
# 'NoneType' object has no attribute 'to_sql'
# Crawler state 2018/06/20 complete!
# Transform state 2018/06/20 complete!
# DB store complete!
# Crawler state 2018/06/21 complete!
# Transform state 2018/06/21 complete!
# DB store complete!
# Crawler state 2018/06/22 complete!
# Transform state 2018/06/22 complete!
# DB store complete!
# Crawler state 2018/06/23 complete!
# Transform state 2018/06/23 complete!
# DB store complete!
# Crawler state 2018/06/24 complete!
# Transform state 2018/06/24 complete!
# DB store complete!
# Crawler state 2018/06/25 complete!
# Transform state 2018/06/25 complete!
# DB store complete!
# Crawler state 2018/06/26 complete!
# Transform state 2018/06/26 complete!
# DB store complete!
# Crawler state 2018/06/27 complete!
# Transform state 2018/06/27 complete!
# DB store complete!
# Crawler state 2018/06/28 complete!
# Transform state 2018/06/28 complete!
# DB store complete!
# Crawler state 2018/06/29 complete!
# Transform state 2018/06/29 complete!
# DB store complete!
# Crawler state 2018/06/30 complete!
# Transform state 2018/06/30 complete!
# DB store complete!
# Crawler state 2018/07/01 complete!
# Transform state 2018/07/01 complete!
# DB store complete!
# Crawler state 2018/07/02 complete!
# Transform state 2018/07/02 complete!
# DB store complete!
# Crawler state 2018/07/03 complete!
# Transform state 2018/07/03 complete!
# DB store complete!
# Crawler state 2018/07/04 complete!
# Transform state 2018/07/04 complete!
# DB store complete!
# Crawler state 2018/07/05 complete!
# Transform state 2018/07/05 complete!
# DB store complete!
# Crawler state 2018/07/06 complete!
# Transform state 2018/07/06 complete!
# DB store complete!
# Crawler state 2018/07/07 complete!
# Transform state 2018/07/07 complete!
# DB store complete!
# Crawler state 2018/07/08 complete!
# Transform state 2018/07/08 complete!
# DB store complete!
# Crawler state 2018/07/09 complete!
# Transform state 2018/07/09 complete!
# DB store complete!
# Crawler state 2018/07/10 complete!
# Transform state 2018/07/10 complete!
# DB store complete!
# Crawler state 2018/07/11 complete!
# Transform state 2018/07/11 complete!
# DB store complete!
# Crawler state 2018/07/12 complete!
# Transform state 2018/07/12 complete!
# DB store complete!
# Crawler state 2018/07/13 complete!
# Transform state 2018/07/13 complete!
# DB store complete!
# Crawler state 2018/07/14 complete!
# Transform state 2018/07/14 complete!
# DB store complete!
# Crawler state 2018/07/15 complete!
# Transform state 2018/07/15 complete!
# DB store complete!
# Crawler state 2018/07/16 complete!
# Transform state 2018/07/16 complete!
# DB store complete!
# Crawler state 2018/07/17 complete!
# Transform state 2018/07/17 complete!
# DB store complete!
# Crawler state 2018/07/18 complete!
# Transform state 2018/07/18 complete!
# DB store complete!
# Crawler state 2018/07/19 complete!
# Transform state 2018/07/19 complete!
# DB store complete!
# Crawler state 2018/07/20 complete!
# Transform state 2018/07/20 complete!
# DB store complete!
# Crawler state 2018/07/21 complete!
# Transform state 2018/07/21 complete!
# DB store complete!
# Crawler state 2018/07/22 complete!
# Transform state 2018/07/22 complete!
# DB store complete!
# Crawler state 2018/07/23 complete!
# Transform state 2018/07/23 complete!
# DB store complete!
# Crawler state 2018/07/24 complete!
# Transform state 2018/07/24 complete!
# DB store complete!
# Crawler state 2018/07/25 complete!
# Transform state 2018/07/25 complete!
# DB store complete!
# Crawler state 2018/07/26 complete!
# Transform state 2018/07/26 complete!
# DB store complete!
# Crawler state 2018/07/27 complete!
# Transform state 2018/07/27 complete!
# DB store complete!
# Crawler state 2018/07/28 complete!
# Transform state 2018/07/28 complete!
# DB store complete!
# Crawler state 2018/07/29 complete!
# Transform state 2018/07/29 complete!
# DB store complete!
# Crawler state 2018/07/30 complete!
# Transform state 2018/07/30 complete!
# DB store complete!
# Crawler state 2018/07/31 complete!
# Transform state 2018/07/31 complete!
# DB store complete!
# Crawler state 2018/08/01 complete!
# Transform state 2018/08/01 complete!
# DB store complete!
# Crawler state 2018/08/02 complete!
# Transform state 2018/08/02 complete!
# DB store complete!
# Crawler state 2018/08/03 complete!
# Transform state 2018/08/03 complete!
# DB store complete!
# Crawler state 2018/08/04 complete!
# Transform state 2018/08/04 complete!
# DB store complete!
# Crawler state 2018/08/05 complete!
# Transform state 2018/08/05 complete!
# DB store complete!
# Crawler state 2018/08/06 complete!
# Transform state 2018/08/06 complete!
# DB store complete!
# Crawler state 2018/08/07 complete!
# Transform state 2018/08/07 complete!
# DB store complete!
# Crawler state 2018/08/08 complete!
# Transform state 2018/08/08 complete!
# DB store complete!
# Crawler state 2018/08/09 complete!
# Transform state 2018/08/09 complete!
# DB store complete!
# Crawler state 2018/08/10 complete!
# Transform state 2018/08/10 complete!
# DB store complete!
# Crawler state 2018/08/11 complete!
# Transform state 2018/08/11 complete!
# DB store complete!
# Crawler state 2018/08/12 complete!
# Transform state 2018/08/12 complete!
# DB store complete!
# Crawler state 2018/08/13 complete!
# Transform state 2018/08/13 complete!
# DB store complete!
# Crawler state 2018/08/14 complete!
# Transform state 2018/08/14 complete!
# DB store complete!
# Crawler state 2018/08/15 complete!
# Transform state 2018/08/15 complete!
# DB store complete!
# Crawler state 2018/08/16 complete!
# Transform state 2018/08/16 complete!
# DB store complete!
# Crawler state 2018/08/17 complete!
# Transform state 2018/08/17 complete!
# DB store complete!
# Crawler state 2018/08/18 complete!
# Transform state 2018/08/18 complete!
# DB store complete!
# Crawler state 2018/08/19 complete!
# Transform state 2018/08/19 complete!
# DB store complete!
# Crawler state 2018/08/20 complete!
# Transform state 2018/08/20 complete!
# DB store complete!
# Crawler state 2018/08/21 complete!
# Transform state 2018/08/21 complete!
# DB store complete!

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="e8575d8ff252650b1b363a37de2bd5a9")>>
